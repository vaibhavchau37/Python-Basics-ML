# %% [markdown]
# # Matplotlib

# %%
figure:canva
axes: individual plots inside the figure

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.linspace(0,10,100)

# %%
y = np.sin(x)

# %%
fig, ax = plt.subplots()
ax.plot(x,y, label = "sin(x)", color = "green")
ax.set_xlabel("x")
ax.set_ylabel("sin(x)")
ax.set_title("sine_wave")
ax.legend()
plt.show()

# %%
np.random.seed(42)

# %%
epochs = np.arange(1,21)

# %%
train_loss = np.exp(-epochs/5) + np.random.rand(20)*0.5

# %%
val_loss = np.exp(-epochs /6) + np.random.rand(20) * 0.08

# %%
plt.plot(epochs,train_loss, label= "train")
plt.plot(epochs , val_loss , label = "validity")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training vs validation loss")
plt.legend()
plt.show()

# %%
## scatter plot

# %%
x = np.random.rand(200)

# %%
y = 2*x + np.random.rand(200)*0.5

# %%
plt.scatter(x,y, alpha = 0.6)

# %%
## boxplot

# %%
models = ["LogReg","RF","SVM","XGB"]
acc= [0.82,0.88,0.85,0.91]

# %%
plt.bar(models,acc,color = "red")
plt.ylabel("accuracy")
plt.xlabel("models")
plt.title("model comparison")
plt.show()

# %%
## histogram

# %%
data = np.random.randn(1000)

# %%
plt.hist(data, bins = 30, color ="red" ,edgecolor = "black")
plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("frequency")
plt.show()

# %%
## subplot

# %%
fig , axes = plt.subplots(1,2, figsize = (10,4))
axes[0].plot(epochs , train_loss)
axes[1].hist(data, bins = 30)
# Out:
# (array([ 4.,  3.,  4., 14., 16., 19., 21., 48., 58., 66., 83., 77., 89.,
#         86., 93., 77., 59., 44., 47., 32., 29., 18.,  7.,  3.,  1.,  1.,
#          0.,  0.,  0.,  1.]),
#  array([-2.99113597, -2.76055685, -2.52997773, -2.2993986 , -2.06881948,
#         -1.83824036, -1.60766124, -1.37708211, -1.14650299, -0.91592387,
#         -0.68534475, -0.45476562, -0.2241865 ,  0.00639262,  0.23697175,
#          0.46755087,  0.69812999,  0.92870911,  1.15928824,  1.38986736,
#          1.62044648,  1.8510256 ,  2.08160473,  2.31218385,  2.54276297,
#          2.77334209,  3.00392122,  3.23450034,  3.46507946,  3.69565858,
#          3.92623771]),
#  <BarContainer object of 30 artists>)

# %%
##Seaborn

# %%
iris = sns.load_dataset("iris")
tips = sns.load_dataset("tips")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data = iris , x ="sepal_length" , hue = "species" ,kde = True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
## Box plot

# %%
sns.boxplot(data = iris , x = "species", y = "petal_length")
plt.title("Box-plot")
plt.show()

# %%
sns.violinplot(data = iris , x = "species" , y = "petal_width")
plt.title("violin plot - distribution shape")
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
corr = iris.drop(columns = ["species"]).corr()

# %%
sns.heatmap(corr , annot = True)
# Out:
# <Axes: >
